# %% [markdown]
# **Haar cascade**

# %% [markdown]
# -  Identifying a custom object in an image is known as object detection.
# -  This task can be done using several techniques,
# -  but we will use the haar cascade, the simplest method to perform object detection

# %% [markdown]
# - Haar cascade is an algorithm that can detect objects in images, irrespective of their scale in image and location.
# - This algorithm is not so complex and can run in real-time.
# - We can train a haar-cascade detector to detect various objects like cars, bikes, buildings, fruits, etc.

# %% [markdown]
# - Haar cascade uses the cascading window, and it tries to compute features in every window and classify whether it could be an object

# %% [markdown]
# <img class="lazy loaded" fetchpriority="high" decoding="async" src="https://cdn-images-1.medium.com/max/1750/1*3itGCmU4Q2INsIaQ0x5Hsw.png" data-src="https://cdn-images-1.medium.com/max/1750/1*3itGCmU4Q2INsIaQ0x5Hsw.png" alt="haar Cascades" width="840" height="582" data-was-processed="true">

# %% [markdown]
# - Haar cascade works as a classifier. It classifies positive data points
# - → that are part of our detected object and negative data points → that don’t contain our object.
#
# - Haar cascades are fast and can work well in real-time.
# - Haar cascade is not as accurate as modern object detection techniques are.
# - Haar cascade has a downside. It predicts many false positives.
# - Simple to implement, less computing power required.

# %%
import cv2
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
import matplotlib.pyplot as plt
img=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\kid.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
img.shape
# Out:
# (1280, 853, 3)

# %% [markdown]
# **now  manually draew a box on image**

# %%
image=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\kid.jpg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
start_window=(150,200)
end_window=(680,780)
color=(200,4,54)
thickness=14
rect_image=cv2.rectangle(img,start_window,end_window,color,thickness)
plt.imshow(rect_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# **now we will use the frontal face**

# %%
img=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\kid.jpg")
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face=face_cascade.detectMultiScale(img,1.1,5)
for x,y,w,h in face:
    print(x)
    print(y)
    print(h)
    print(w)
# Out:
# 141
# 331
# 483
# 483

# %%
rectangle_image=cv2.rectangle(img,(x,y),(x+w,y+h),(225,55,10),5)
image=cv2.cvtColor(rectangle_image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %% [markdown]
# **try with other images**

# %%
image_1=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\multiplepeople.jpg")
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
face=face_cascade.detectMultiScale(image_1,1.1,2)
list_1={}
count=0
for x,y,w,h in face:
    list_1["person {}".format(count)]=[x,y,w,h]
    count+=1
print(list_1)
rectange_image_1=cv2.rectangle(image_1,(x,y),(x+w,y+h),(225,55,10),5)
converted_image=cv2.cvtColor(rectange_image_1,cv2.COLOR_BGR2RGB)
plt.imshow(converted_image)
plt.show()
# Out:
# {'person 0': [26, 95, 32, 32], 'person 1': [456, 249, 86, 86], 'person 2': [59, 170, 67, 67], 'person 3': [266, 180, 55, 55], 'person 4': [633, 119, 32, 32], 'person 5': [804, 170, 75, 75], 'person 6': [383, 111, 54, 54], 'person 7': [825, 114, 45, 45]}

# %%
image_1=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\father.jpg")
face_cascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
face=face_cascade.detectMultiScale(image_1,1.1,2)
list_1={}
count=0
for x,y,w,h in face:
    list_1["person {}".format(count)]=[x,y,w,h]
    count+=1

# %%
list_1
# Out:
# {'person 0': [706, 279, 116, 116],
#  'person 1': [650, 140, 27, 27],
#  'person 2': [534, 482, 52, 52],
#  'person 3': [622, 201, 55, 55],
#  'person 4': [410, 325, 114, 114]}

# %%
rectange_image_1=cv2.rectangle(image_1,(x,y),(x+w,y+h),(225,55,10),5)
converted_image=cv2.cvtColor(rectange_image_1,cv2.COLOR_BGR2RGB)
plt.imshow(converted_image)

# %% [markdown]
# **eyes**

# %%
eye_img=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\kid.jpg")
eye_cascade=cv2.CascadeClassifier('haarcascade_eye.xml')
eye=eye_cascade.detectMultiScale(eye_img,1.1,5)
for x,y,w,h in eye:
    print(x)
    print(y)
    print(h)
    print(w)
# Out:
# 343
# 596
# 48
# 48
# 401
# 465
# 107
# 107
# 249
# 482
# 94
# 94
# 378
# 598
# 49
# 49

# %%
rectangle_image=cv2.rectangle(eye_img,(x,y),(x+w,y+h),(225,55,10),5)
image=cv2.cvtColor(rectangle_image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
smile_image=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\smile.jpg")
smile=cv2.CascadeClassifier("haarcascade_smile.xml")
smile_face=smile.detectMultiScale(smile_image,1.1,2)
for x,y,w,h in smile_face:
    print(x,y,w,h)
# Out:
# 15 745 68 34
# 769 92 230 115
# 406 501 85 43
# 768 150 332 166
# 427 93 391 196
# 542 248 91 45
# 886 371 94 47
# 765 349 129 64
# 705 695 55 27
# 813 621 55 28
# 690 721 57 28
# 551 344 110 55
# 703 568 76 38
# 820 597 84 42
# 610 208 203 102
# 797 407 171 86
# 873 657 154 77
# 417 265 267 134
# 851 566 291 146
# 600 343 434 217
# 653 387 117 58
# 532 294 68 34
# 842 294 78 39
# 881 575 161 81
# 30 402 565 283
# 513 309 109 54
# 1054 154 134 67
# 483 366 227 114

# %%
smile_rectangle=cv2.rectangle(smile_image,(x,y),(x+w,y+h),(225,55,10),4)
smile_rectangle=cv2.cvtColor(smile_rectangle,cv2.COLOR_BGR2RGB)
plt.imshow(smile_rectangle)
plt.show()

# %%
smile_image_1=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\smilekid.jpg")
smile=cv2.CascadeClassifier("haarcascade_smile.xml")
smile_face=smile.detectMultiScale(smile_image_1,1.1,2)
for x,y,w,h in smile_face:
    print(x,y,w,h)
smile_rectangle=cv2.rectangle(smile_image_1,(x,y),(x+w,y+h),(225,55,10),4)
smile_rectangle=cv2.cvtColor(smile_rectangle,cv2.COLOR_BGR2RGB)
plt.imshow(smile_rectangle)
plt.show()
# Out:
# 54 151 61 31
# 106 142 74 37
# 22 48 48 24
# 49 41 81 41
# 6 90 73 37
# 95 76 98 49
# 137 6 96 48

# %% [markdown]
# **fullbody detection**

# %%
children=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\childrens.jpg")
full_image=cv2.CascadeClassifier("haarcascade_smile.xml")
faces=full_image.detectMultiScale(children,1.1,2)
for x,y,w,h in faces:
    print(x,y,w,h)
rectangle=cv2.rectangle(children,(x,y),(x+w,y+h),(225,55,10),4)
rectangle=cv2.cvtColor(rectangle,cv2.COLOR_BGR2RGB)
plt.imshow(rectangle)
plt.show()
# Out:
# 189 368 41 20
# 289 355 59 30
# 389 360 51 26
# 497 374 37 18
# 591 373 36 18
# 253 365 52 26
# 329 348 56 28
# 134 378 53 27
# 473 381 37 19
# 80 388 36 18
# 103 389 40 20
# 188 391 41 21
# 318 393 43 21
# 413 19 102 51
# 123 395 41 21
# 363 112 72 36
# 373 220 76 38
# 191 138 91 46
# 222 173 181 91
# 150 112 117 58
# 191 6 182 91
# 469 264 86 43
# 508 384 44 22
# 353 5 234 117
# 167 246 93 47
# 237 154 89 44
# 85 338 69 35
# 316 109 171 86
# 533 367 39 20
# 504 340 65 32
# 317 374 50 25
# 389 223 211 106
# 63 361 56 28
# 364 354 116 58
# 12 30 100 50
# 184 97 42 21
# 102 301 50 25
# 349 150 100 50
# 450 340 141 70
# 239 401 38 19
# 448 332 37 19
# 394 328 42 21
# 590 344 36 18
# 37 274 213 107
# 389 303 77 39
# 478 303 79 39
# 78 291 84 42
# 420 316 38 19
# 324 313 39 20
# 317 320 38 19
# 248 321 36 18
# 165 327 76 38
# 478 360 36 18

# %%
children=cv2.imread("D:\\DEEP LEARNING\\open cv\\images\\childrens.jpg")
full_image=cv2.CascadeClassifier("haarcascade_fullbody.xml")
faces=full_image.detectMultiScale(children,1.1,2)
for x,y,w,h in faces:
    print(x,y,w,h)
rectangle=cv2.rectangle(children,(x,y),(x+w,y+h),(225,55,10),4)
rectangle=cv2.cvtColor(rectangle,cv2.COLOR_BGR2RGB)
plt.imshow(rectangle)
plt.show()
# Out:
# 362 299 52 105

# %%
face_cascade=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade=cv2.CascadeClassifier('haarcascade_eye.xml')
smile_cascade=cv2.CascadeClassifier("haarcascade_smile.xml")

# %% [markdown]
# **videos**

# %%
video=cv2.VideoCapture(0)
while video.isOpened():
    ret,frame=video.read()
    faces=face_cascade.detectMultiScale(frame,1.1,4)
    for x,y,w,h in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(225,55,10),5)
        cv2.imshow('image',frame)
    if cv2.waitKey(1) & 0xFF== ord('q'):
        break
video.release()
cv2.destroyAllWindows()

# %% [markdown]
# **with eye balls and smiles**

# %%
video=cv2.VideoCapture(0)
while video.isOpened():
    ret,frame=video.read()
    faces=face_cascade.detectMultiScale(frame,1.1,4)
    for x,y,w,h in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(225,55,10),5)
    roi_color=frame[y:y+h,x:x+w]
    eyes=eye_cascade.detectMultiScale(roi_color)
    for ex,ey,ew,eh in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(225,55,10),5)
    cv2.imshow("image",frame)
    if cv2.waitKey(1) & 0xFF== ord('q'):
        break
video.release()
cv2.destroyAllWindows()
